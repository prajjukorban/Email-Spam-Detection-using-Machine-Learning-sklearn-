# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("combined_data.csv")

# %%
df
# Out:
#        label                                               text
# 0          1  ounce feather bowl hummingbird opec moment ala...
# 1          1  wulvob get your medircations online qnb ikud v...
# 2          0   computer connection from cnn com wednesday es...
# 3          1  university degree obtain a prosperous future m...
# 4          0  thanks for all your answers guys i know i shou...
# ...      ...                                                ...
# 83443      0  hi given a date how do i get the last date of ...
# 83444      1  now you can order software on cd or download i...
# 83445      1  dear valued member canadianpharmacy provides a...
# 83446      0  subscribe change profile contact us long term ...
# 83447      1  get the most out of life ! viagra has helped m...
#
# [83448 rows x 2 columns]

# %%
y = df['label']

# %%
X = df["text"]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# %%
import joblib
joblib.dump(vectorizer,"vectorizer.joblib")
# Out:
# ['vectorizer.joblib']

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier()

# %%
model.fit(X_train_vec,y_train)
# Out:
# RandomForestClassifier()

# %%
model.predict(X_test_vec)
# Out:
# array([1, 1, 0, ..., 0, 0, 0], dtype=int64)

# %%
model.score(X_test_vec,y_test)
# Out:
# 0.9825044937088077

# %%
pred = input("Enter your email: ")
pred_vec = vectorizer.transform([pred])  # Always use transform, and wrap in list
prediction = model.predict(pred_vec)

print("Result:","🛑Spam" if prediction[0] == 1 else "✅Not Spam")
# Out:
# Enter your email:  sdfvvzdfgsrtb
# Result: 🛑Spam

# %%
df['text'][50],df['label'][50]
# Out:
# ("hi folks now that we've had more experience with running things on the xo i feel that the default big arrow cursor is too big it really gets in the way of many kinds of pointing and hitting operations text small buttons etc what do you think could we make this cursor smaller could we make its shape a little more pleasing cheers alan sugar mailing list sugar lists laptop org http lists laptop org listinfo sugar",
#  0)

# %%
y_pred = model.predict(X_test_vec)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

acc = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred)
rec = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("✅ Accuracy:", acc)
print("✅ Precision:", prec)
print("✅ Recall:", rec)
print("✅ F1 Score:", f1)
# Out:
# ✅ Accuracy: 0.9825044937088077
# ✅ Precision: 0.9839553937187073
# ✅ Recall: 0.9828370084110025
# ✅ F1 Score: 0.9833958830888206

# %%
import joblib

joblib.dump(model,"email spam.joblib")
# Out:
# ['email spam.joblib']
